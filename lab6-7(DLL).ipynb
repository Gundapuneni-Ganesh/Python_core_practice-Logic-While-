# %% [raw]
# => Double Lined List
#     * this is two way communication . where can move forward and backward
#     * DLL has prev node and next node adress . so it can move forward and backward
#     *

# %%
# Forward travesing the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
            
ob = DLL()
ob.forward_trav()
# Out:
# Double Linked List is empty

# %%
# Backward travesing the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        # print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        # print("None")

            
ob = DLL()
ob.forward_trav()

ob.backward_trav()
# Out:
# Double Linked List is empty
# DLL is empty

# %%
# Inserting at begin at  the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")

    def insert_begin(self,val): # inserting at begin
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        
ob = DLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.insert_begin(14)
ob.forward_trav()

ob.backward_trav()
# Out:
# 14<-->13<-->12<-->11<-->None
# 11<-->12<-->13<-->14<-->None

# %%
# Inserting at last at  the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")

    def insert_begin(self,val): # inserting at begin
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        
    def insert_last(self,val): # inserting at last
        newnode= Node(val)
        temp = self.head
        if self.head is None:
            print("list is empty")
            self.head = newnode
            return
        while temp.next != None:
            temp = temp.next
        temp.next = newnode
        newnode.next = None
        newnode.prev = temp
        
ob = DLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.insert_begin(14)

ob.insert_last(15)

ob.forward_trav()

ob.backward_trav()
# Out:
# 14<-->13<-->12<-->11<-->15<-->None
# 15<-->11<-->12<-->13<-->14<-->None

# %%
# Deletion at starting of the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")

    def insert_begin(self,val): # inserting at begin
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        
    def insert_last(self,val): # inserting at last
        newnode= Node(val)
        temp = self.head
        if self.head is None:
            print("list is empty")
            self.head = newnode
            return
        while temp.next != None:
            temp = temp.next
        temp.next = newnode
        newnode.next = None
        newnode.prev = temp

    def deletion_start(self): # deletion at starting value
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        self.head = temp.next
        temp.prev = None

    
        
ob = DLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.insert_begin(14)

# ob.insert_last(15)

ob.deletion_start()
ob.forward_trav()

# ob.backward_trav()
# Out:
# 13<-->12<-->11<-->None

# %%
# Deletion at ending of the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")

    def insert_begin(self,val): # inserting at begin
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        
    def insert_last(self,val): # inserting at last
        newnode= Node(val)
        temp = self.head
        if self.head is None:
            print("list is empty")
            self.head = newnode
            return
        while temp.next != None:
            temp = temp.next
        temp.next = newnode
        newnode.next = None
        newnode.prev = temp

    def deletion_start(self): # deletion at starting value
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        self.head = temp.next
        temp.prev = None

    def deletion_end(self):  # deletion at ending
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return

        if self.head.next is None:
            self.head = None
            return
            
        while temp.next != None:
            temp = temp.next
        temp.prev.next = None

    
        
        
ob = DLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.insert_begin(14)

# ob.insert_last(15)

ob.deletion_start()

ob.deletion_end()

ob.forward_trav()

# ob.backward_trav()
# Out:
# 13<-->12<-->None

# %%
# Deletion at position of the double liked list

class Node:                 # creation of DLL nodes
    def __init__(self,val):
        self.data = val
        self.prev = None
        self.next = None
        
class DLL:
    def __init__(self):
        self.head = None
        
    def forward_trav(self): # forward travesing of elements
        temp = self.head
        if self.head == None:
            print("Double Linked List is empty")
        while temp!=None:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
            
    def backward_trav(self):   # backward traversal of elements 
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        while temp.next is not None:
            temp = temp.next
        while temp != None:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")

    def insert_begin(self,val): # inserting at begin
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        newnode.next = self.head
        self.head.prev = newnode
        self.head = newnode
        
    def insert_last(self,val): # inserting at last
        newnode= Node(val)
        temp = self.head
        if self.head is None:
            print("list is empty")
            self.head = newnode
            return
        while temp.next != None:
            temp = temp.next
        temp.next = newnode
        newnode.next = None
        newnode.prev = temp

    def deletion_start(self): # deletion at starting value
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return
        self.head = temp.next
        temp.prev = None

    def deletion_end(self):  # deletion at ending
        temp = self.head
        if self.head == None:
            print("DLL is empty")
            return

        if self.head.next is None:
            self.head = None
            return
            
        while temp.next != None:
            temp = temp.next
        temp.prev.next = None


    def deletion_pos(self,pos): # deletion at postion
        cur_pos = 1
        temp = self.head
        
        if pos < 1:
            print("Invalid position")
            return
        elif pos == 1 and self.head is None:
            self.head = None
            return
        while temp.next !=
            

    
        
        
ob = DLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.insert_begin(14)

# ob.insert_last(15)

ob.deletion_start()

ob.deletion_end()

ob.forward_trav()

# ob.backward_trav()
