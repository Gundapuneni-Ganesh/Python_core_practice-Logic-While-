# %% [raw]
# => Data Structures
#     linear = array , stack ,queses,linked list
#     non linear = trees , graphs,hash tables , tries

# %% [raw]
# # linked List
#      It is collection of nodes

# %%
# linked list travelsal of elements
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(self.data,end="-->")
            temp = temp.next
ob = SLL()
ob.travelsal()
# Out:
# LL is empty

# %%
# inserting a node at the beginning

class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")

    def insert_begin(self,val): # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal()
# Out:
# 13-->12-->11-->NULL

# %%
# inserting a node at the ending

class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")

    def insert_begin(self,val): # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val): # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

        
ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL

# %%
# inserting a node at the position

class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")

    def insert_begin(self,val): # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val): # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

    def inser_pos(self,pos,val): # inserting at position
        cur_pos = 1
        temp = self.head
        newnode = Node(val)
        if pos  < 1:
            print("Invalid opstion")
            return
        elif pos == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("position is out of range")
            return
        newnode.next = temp.next
        temp.next = newnode
                
ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending

ob.inser_pos(5,555)
ob.travelsal() # prints the inserting value at fifth position
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL
# 13-->12-->11-->114-->555-->115-->116-->NULL

# %%
# Deletion a node at the Begining

class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")

    def insert_begin(self,val): # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val): # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

    def inser_pos(self,pos,val): # inserting at position
        cur_pos = 1
        temp = self.head
        newnode = Node(val)
        if pos  < 1:
            print("Invalid opstion")
            return
        elif pos == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("position is out of range")
            return
        newnode.next = temp.next
        temp.next = newnode
        
    def delete_start(self): # delete at starting value
        if self.head is None:
            print("List is empty")
            return
        self.head = self.head.next

                
ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending

ob.inser_pos(5,555)
ob.travelsal() # prints the inserting value at fifth position

ob.delete_start()
ob.travelsal() # delete the starting node
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL
# 13-->12-->11-->114-->555-->115-->116-->NULL
# 12-->11-->114-->555-->115-->116-->NULL

# %%
# Deletion a node at the ending

class Node:  # creating of node structure and insrting data
    def __init__(self,value):
        self.data = value
        self.next = None
#----------------------------------------------------------------------------------------        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):                 # travelsel or iterating
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")
#----------------------------------------------------------------------------------------
    def insert_begin(self,val):          # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val):           # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

    def inser_pos(self,pos,val):       # inserting at position
        cur_pos = 1
        temp = self.head
        newnode = Node(val)
        if pos  < 1:
            print("Invalid opstion")
            return
        elif pos == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("position is out of range")
            return
        newnode.next = temp.next
        temp.next = newnode
#----------------------------------------------------------------------------------------      
    def delete_start(self):    # delete at starting value
        if self.head is None:
            print("List is empty")
            return
        self.head = self.head.next


    def delete_end(self):     # delete at the ending
        temp = self.head
        prev = None
        if self.head == None:
            print("List are empty")
            return
        elif self.head.next == None:
            self.head = None
            return
        while temp.next != None:
            prev= temp
            temp = temp.next
        prev.next = None
#------------------------------------------------------------------------------------------        

ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending

ob.inser_pos(5,555)
ob.travelsal() # prints the inserting value at fifth position

ob.delete_start()
ob.travelsal() # delete the starting node

ob.delete_end()
ob.travelsal() # delete the ending node
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL
# 13-->12-->11-->114-->555-->115-->116-->NULL
# 12-->11-->114-->555-->115-->116-->NULL
# 12-->11-->114-->555-->115-->NULL

# %%
# Deletion a node at the position

class Node:  # creating of node structure and insrting data
    def __init__(self,value):
        self.data = value
        self.next = None
#----------------------------------------------------------------------------------------        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):                 # travelsel or iterating
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")
#----------------------------------------------------------------------------------------
    def insert_begin(self,val):          # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val):           # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

    def inser_pos(self,pos,val):       # inserting at position
        cur_pos = 1
        temp = self.head
        newnode = Node(val)
        if pos  < 1:
            print("Invalid opstion")
            return
        elif pos == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("position is out of range")
            return
        newnode.next = temp.next
        temp.next = newnode
#----------------------------------------------------------------------------------------      
    def delete_start(self):    # delete at starting value
        if self.head is None:
            print("List is empty")
            return
        self.head = self.head.next
        

    def delete_end(self):     # delete at the ending
        temp = self.head
        prev = None
        if self.head == None:
            print("List are empty")
            return
        elif self.head.next == None:
            self.head = None
            return
        while temp.next != None:
            prev= temp
            temp = temp.next
        prev.next = None


    def delete_pos(self,pos): # deletion at position
        temp = self.head
        cur_pos = 1
        if pos < 1:
            print("enter the valid position")
            return
        elif self.head == None:
            print("list are empty")
        if pos == 1:
            self.head = None 
            return
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("Out of range")
            return
        temp.next = temp.next.next
        
        
            
        
            
            
            
#------------------------------------------------------------------------------------------        

ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending

ob.inser_pos(5,555)
ob.travelsal() # prints the inserting value at fifth position

ob.delete_start()
ob.travelsal() # delete the starting node

ob.delete_end()
ob.travelsal() # delete the ending node

ob.delete_pos(3)
ob.delete_pos(4)
ob.travelsal() # delete the position node
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL
# 13-->12-->11-->114-->555-->115-->116-->NULL
# 12-->11-->114-->555-->115-->116-->NULL
# 12-->11-->114-->555-->115-->NULL
# LL is empty
# NULL

# %%
# Deletion a node at the position

class Node:  # creating of node structure and insrting data
    def __init__(self,value):
        self.data = value
        self.next = None
#----------------------------------------------------------------------------------------        
class SLL:
    def __init__(self):
        self.head = None
        
    def travelsal(self):                 # travelsel or iterating
        if self.head == None:
            print("LL is empty")
        temp = self.head
        while temp!=None:
            print(temp.data,end="-->")
            temp = temp.next
        print("NULL")
#----------------------------------------------------------------------------------------
    def insert_begin(self,val):          # inserting code at begin 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
        else:
            newnode.next = self.head
            self.head = newnode
            
    def insert_end(self, val):           # insert at ending 
        newnode = Node(val)
        if self.head is None:
            self.head = newnode
            return
        temp = self.head
        while temp.next is not None:
            temp = temp.next
        temp.next = newnode

    def inser_pos(self,pos,val):       # inserting at position
        cur_pos = 1
        temp = self.head
        newnode = Node(val)
        if pos  < 1:
            print("Invalid opstion")
            return
        elif pos == 1:
            newnode.next = self.head
            self.head = newnode
            return
        
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("position is out of range")
            return
        newnode.next = temp.next
        temp.next = newnode
#----------------------------------------------------------------------------------------    
    
#     def delete_start(self):    # delete at starting value
#         if self.head is None:
#             print("List is empty")
#             return
#         self.head = self.head.next
        

#     def delete_end(self):     # delete at the ending
#         temp = self.head
#         prev = None
#         if self.head == None:
#             print("List are empty")
#             return
#         elif self.head.next == None:
#             self.head = None
#             return
#         while temp.next != None:
#             prev= temp
#             temp = temp.next
#         prev.next = None


    def delete_pos(self,pos): # deletion at position
        temp = self.head 
        cur_pos = 1
        if pos < 1:
            print("enter the valid position")
            return
        elif self.head == None:
            print("list are empty")
        if pos == 1:
            self.head = None 
            return
        while temp != None and cur_pos < pos-1:
            temp = temp.next
            cur_pos +=1
        if temp == None:
            print("Out of range")
            return
        temp.next = temp.next.next
        
#------------------------------------------------------------------------------------------        

ob = SLL()
ob.insert_begin(11)
ob.insert_begin(12)
ob.insert_begin(13)
ob.travelsal() # prints the starting at begin

ob.insert_end(114)
ob.insert_end(115)
ob.insert_end(116)
ob.travelsal() # prints the inserting at ending

ob.inser_pos(5,555)
ob.travelsal() # prints the inserting value at fifth position

# ob.delete_start()
# ob.travelsal() # delete the starting node

# ob.delete_end()
# ob.travelsal() # delete the ending node

ob.delete_pos(3)
ob.delete_pos(5)
ob.delete_pos(-4)
ob.travelsal() # delete the position node
# Out:
# 13-->12-->11-->NULL
# 13-->12-->11-->114-->115-->116-->NULL
# 13-->12-->11-->114-->555-->115-->116-->NULL
# enter the valid position
# 13-->12-->114-->555-->116-->NULL
